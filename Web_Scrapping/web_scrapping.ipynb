# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_rul="https://www.flipkart.com/search?q=" + "tv"

# %%
flipkart_rul
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
url_client=urlopen(flipkart_rul)

# %%
flipkart_page=url_client.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"www.flipkart.com"+"/blaupunkt-cybersound-g2-series-80-cm-32-inch-hd-ready-led-smart-android-tv-2023-dolby-digital-plus-40-w-sound-output/p/itm4a4c48379c152?pid=TVSGQFRY28WQPTFW&lid=LSTTVSGQFRY28WQPTFWWULMMJ&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_8lFyKsavVaP2CTvcCvSuXsDSpIcqTUtxkn7RnpQZU8AjwwQ0WveMI_6uNJd6q0rXmfcpuHOlC8hVWsOCWJb6Pw%3D%3D&ppt=None&ppn=None&ssid=al7in7nxog0000001716204611579&qH=c9a1fdac6e082dd8"
# Out:
# 'www.flipkart.com/blaupunkt-cybersound-g2-series-80-cm-32-inch-hd-ready-led-smart-android-tv-2023-dolby-digital-plus-40-w-sound-output/p/itm4a4c48379c152?pid=TVSGQFRY28WQPTFW&lid=LSTTVSGQFRY28WQPTFWWULMMJ&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_8lFyKsavVaP2CTvcCvSuXsDSpIcqTUtxkn7RnpQZU8AjwwQ0WveMI_6uNJd6q0rXmfcpuHOlC8hVWsOCWJb6Pw%3D%3D&ppt=None&ppn=None&ssid=al7in7nxog0000001716204611579&qH=c9a1fdac6e082dd8'

# %%
big_box=flipkart_html.find_all("div",{"class":"cPHDOP col-12-12"})

# %%
len(big_box)
# Out:
# 30

# %%
del big_box[0:2]

# %%
product_link = "https://www.flipkart.com" + big_box[0].div.div.div.a['href']

# %%
for i in big_box:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/mi-series-80-cm-32-inch-hd-ready-led-smart-google-tv-2023-dolby-audio-dts-hd-vivid-picture-engine/p/itmf15b4727d84f5?pid=TVSGREPAZX8CN9QS&lid=LSTTVSGREPAZX8CN9QS4JKYUB&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=FkPickId_ckf%2Fczl&srno=s_1_4&otracker=search&fm=organic&iid=6fd5afcf-0126-4a1f-92dc-3cf1902a6b44.TVSGREPAZX8CN9QS.SEARCH&ppt=None&ppn=None&ssid=owf00nw4nk0000001716207161823&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/thomson-alpha-60-cm-24-inch-hd-ready-led-smart-linux-tv-2023-20-w-sound-output/p/itm8e1f318f88ccc?pid=TVSGMGWWZYMMPG83&lid=LSTTVSGMGWWZYMMPG83APKNG2&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_5&otracker=search&fm=organic&iid=6fd5afcf-0126-4a1f-92dc-3cf1902a6b44.TVSGMGWWZYMMPG83.SEARCH&ppt=None&ppn=None&ssid=owf00nw4nk0000001716207161823&qH=c9a1fdac6e082dd8
# ...

# %%
product_link
# Out:
# 'https://www.flipkart.com/mi-series-80-cm-32-inch-hd-ready-led-smart-google-tv-2023-dolby-audio-dts-hd-vivid-picture-engine/p/itmf15b4727d84f5?pid=TVSGREPAZX8CN9QS&lid=LSTTVSGREPAZX8CN9QS4JKYUB&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=FkPickId_ckf%2Fczl&srno=s_1_4&otracker=search&fm=organic&iid=6fd5afcf-0126-4a1f-92dc-3cf1902a6b44.TVSGREPAZX8CN9QS.SEARCH&ppt=None&ppn=None&ssid=owf00nw4nk0000001716207161823&qH=c9a1fdac6e082dd8'

# %%
requests.get(product_link)
# Out:
# <Response [500]>

# %%
product_req.text
# Out:
# '<html><body><h1>500 Internal Server Error</h1>\nAn internal server error occurred.\n</body></html>\n'

# %%
bs(product_request.text,'html.parser')
# Out:
# <html><body><h1>500 Internal Server Error</h1>
# An internal server error occurred.
# </body></html>
