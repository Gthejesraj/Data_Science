# %% [markdown]
# ### 5 number summary and Box Plot

# %%
## Minimum,Q1,Median,Q3,Maximum

# %%
import numpy as np
import seaborn as sns

# %%
list_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(list_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (32.0, 54.0, 67.0, 89.0, 99.0)

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# 1.5

# %%
higher_fence
# Out:
# 141.5

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks=[-100,-50,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,200,250,300]

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >
