# %% [markdown]
# ### SMOTE(Synthetic Minority Oversampling Technique)
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                   weights=[0.90],random_state=12)

# %%
import pandas as pd
df1 = pd.DataFrame(X,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df=  pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /opt/anaconda3/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from imbalanced-learn) (2.2.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
conda install -c conda-forge imbalanced-learn
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - imbalanced-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.6.2   |       h8857fd0_0         152 KB  conda-forge
#     certifi-2024.6.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     conda-24.1.2               |  py311h6eed73b_0         1.2 MB  conda-forge
#     imbalanced-learn-0.12.3    |     pyhd8ed1ab_0         155 KB  conda-forge
#     openssl-3.3.1              |       h87427d6_0         2.4 MB  conda-forge
#     packaging-24.0             |     pyhd8ed1ab_0          49 KB  conda-forge
#     python_abi-3.11            |          2_cp311           5 KB  conda-forge
#     setuptools-70.0.0          |     pyhd8ed1ab_0         472 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   packaging          conda-forge/noarch::packaging-24.0-pyhd8ed1ab_0
#   python_abi         conda-forge/osx-64::python_abi-3.11-2_cp311
#   setuptools         conda-forge/noarch::setuptools-70.0.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.12.12~ --> conda-forge::ca-certificates-2024.6.2-h8857fd0_0
#   certifi            pkgs/main/osx-64::certifi-2024.2.2-py~ --> conda-forge/noarch::certifi-2024.6.2-pyhd8ed1ab_0
#   imbalanced-learn   pkgs/main/osx-64::imbalanced-learn-0.~ --> conda-forge/noarch::imbalanced-learn-0.12.3-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-3.0.13-hca72f7f_0 --> conda-forge::openssl-3.3.1-h87427d6_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-24.1.2-py311hecd8cb5~ --> conda-forge::conda-24.1.2-py311h6eed73b_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.3.1        | 2.4 MB    |                                       |   0%
# conda-24.1.2         | 1.2 MB    |                                       |   0%
#
# setuptools-70.0.0    | 472 KB    |                                       |   0%
#
#
# certifi-2024.6.2     | 157 KB    |                                       |   0%
#
#
#
# imbalanced-learn-0.1 | 155 KB    |                                       |   0%
#
#
#
#
# ca-certificates-2024 | 152 KB    |                                       |   0%
#
#
#
#
#
# packaging-24.0       | 49 KB     |                                       |   0%
#
#
#
#
#
#
# python_abi-3.11      | 5 KB      |                                       |   0%
#
# setuptools-70.0.0    | 472 KB    | #2                                    |   3%
#
#
#
# imbalanced-learn-0.1 | 155 KB    | ###8                                  |  10%
#
# setuptools-70.0.0    | 472 KB    | ####################                  |  54%
#
#
# openssl-3.3.1        | 2.4 MB    | 2                                     |   1%
#
# setuptools-70.0.0    | 472 KB    | ###################################1  |  95%
#
#
#
# imbalanced-learn-0.1 | 155 KB    | ##############################5       |  82%
# conda-24.1.2         | 1.2 MB    | 4                                     |   1%
#
#
# openssl-3.3.1        | 2.4 MB    | ###                                   |   8%
#
#
# certifi-2024.6.2     | 157 KB    | ##################################### | 100%
#
#
#
#
# ca-certificates-2024 | 152 KB    | ###8                                  |  10%
# conda-24.1.2         | 1.2 MB    | ####8                                 |  13%
#
#
#
#
# openssl-3.3.1        | 2.4 MB    | #####2                                |  14%
#
#
#
# imbalanced-learn-0.1 | 155 KB    | ##################################### | 100%
# conda-24.1.2         | 1.2 MB    | #######2                              |  19%
#
# setuptools-70.0.0    | 472 KB    | ##################################### | 100%
#
#
#
#
#
# openssl-3.3.1        | 2.4 MB    | #########                             |  24%
#
#
#
#
#
# packaging-24.0       | 49 KB     | ##################################### | 100%
# openssl-3.3.1        | 2.4 MB    | ############3                         |  33%
#
#
#
#
#
#
# python_abi-3.11      | 5 KB      | ##################################### | 100%
#
#
#
#
#
#
# python_abi-3.11      | 5 KB      | ##################################### | 100%
# openssl-3.3.1        | 2.4 MB    | ##############9                       |  41%
# openssl-3.3.1        | 2.4 MB    | ###################5                  |  53%
# openssl-3.3.1        | 2.4 MB    | ##################################### | 100%
# conda-24.1.2         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
## transform the dataset
oversample=SMOTE()
X,y = oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
oversample_df= pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])
